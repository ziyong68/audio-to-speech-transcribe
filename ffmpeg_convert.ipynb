# %%
import os
os.getcwd()
# Out:
# '/Users/angeldog/Documents/LLM'

# %%
# import ffmpeg # Install this package yourself in whisper_env
import subprocess

# %%
input_file = "./Malcom class 1 audio.m4a"  # Replace with your m4a, mp4, webm,... file path
output_mp3_file = "./Malcom class 1 audio.mp3"  # Replace with desired output MP3 file path

# Can you turn this into a folder parameter and wrap the function below in a loop to work on non mp3 files within the folder?

# %%
def convert_to_mp3(input_file, output_file):
    command = [
        "ffmpeg",
        "-i", input_file,   # Input file (WEBM)
        "-q:a", "0",        # Best audio quality
        "-map", "a",        # Extract audio only
        output_file         # Output file (MP3)
    ]
    
    subprocess.run(command, check=True)
    print(f"Conversion complete: {output_file}")

# %%
convert_to_mp3(input_file, output_mp3_file)
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with clang version 14.0.6
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --ar=arm64-apple-darwin20.0.0-ar --nm=arm64-apple-darwin20.0.0-nm --ranlib=arm64-apple-darwin20.0.0-ranlib --strip=arm64-apple-darwin20.0.0-strip --disable-doc --enable-swresample --enable-swscale --enable-openssl --enable-libxml2 --enable-libtheora --enable-demuxer=dash --enable-postproc --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libdav1d --enable-zlib --enable-libaom --enable-pic --enable-shared --disable-static --disable-gpl --enable-version3 --disable-sdl2 --enable-libopenh264 --enable-libopus --enable-libmp3lame --enable-libopenjpeg --enable-libvorbis --enable-pthreads --enable-libtesseract --enable-libvpx --enable-librsvg
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './Malcom class 1 audio.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2025-06-30T13:23:19.000000Z
#     iTunSMPB        :  00000000 00000840 00000000 0000000009D96BC0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#   Duration: 00:57:22.62, start: 0.044000, bitrate: 245 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 244 kb/s (default)
#     Metadata:
#       creation_time   : 2025-06-30T13:23:19.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './Malcom class 1 audio.mp3':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     iTunSMPB        :  00000000 00000840 00000000 0000000009D96BC0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     TSSE            : Lavf60.16.100
#   Stream #0:0(und): Audio: mp3, 48000 Hz, mono, fltp (default)
#     Metadata:
#       creation_time   : 2025-06-30T13:23:19.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libmp3lame
# size=   52736kB time=00:56:06.07 bitrate= 128.3kbits/s speed= 217x
# Conversion complete: ./Malcom class 1 audio.mp3
# [out#0/mp3 @ 0x14ee18590] video:0kB audio:54152kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000849%
# size=   54153kB time=00:57:22.56 bitrate= 128.9kbits/s speed= 217x

# %%
subprocess.run(["pwd"])
# Out:
# /Users/angeldog/Documents/LLM
# CompletedProcess(args=['pwd'], returncode=0)

# %%
os.getcwd()
# Out:
# '/Users/angeldog/Documents/LLM'
